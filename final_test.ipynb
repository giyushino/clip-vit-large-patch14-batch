# %%
# !pip install transformers
# !pip install torch
# !pip install datasets
from transformers import CLIPProcessor, CLIPModel
import torch
from datasets import load_dataset
import torch.optim as optim
import torch.nn.functional as F
import time
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 14.7 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.4 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 15.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.9 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 11.4 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
# Load cifar10 dataset and extract labels
datasets = load_dataset("cifar10")

labels = datasets["train"].features["label"].names
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = i
    id2label[i] = label
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/5.16k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/120M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/23.9M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]

# %%
#Load model and processor from Hugging Face's transformers library
model = CLIPModel.from_pretrained("openai/clip-vit-large-patch14")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-large-patch14")
# Out:
# config.json:   0%|          | 0.00/4.52k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/905 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/961k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# Function to batch large datasets into smaller groups for easier computation
def homemade_batch(num_img, batch_size=10, start_img=0, data_type = "test"):
    # Initialize empty set to store predicted values and their probabilities
    homemade = []
    num_batches = num_img // batch_size
    extra = num_img % batch_size # Not implemented yet

    # Allows computations to be run on GPU instead of CPU
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    t_0 = time.perf_counter()

    for i in range(num_batches):
        t1 = time.perf_counter()

        # Create a temporary batch of data
        subset = datasets[data_type].select(range((i * batch_size + start_img), (i + 1) * batch_size + start_img))
        input = processor(text=labels, images=subset["img"], return_tensors="pt", padding=False).to(device)
        output = model(**input)

        # Access logits of the input images, apply softmax function
        logits = output.logits_per_image
        probs = logits.softmax(dim=1)

        # Find maximum of the probabilities, as well as their corresponding index, append them to list
        max_prob, max_id = probs.max(dim=1)
        homemade.append([max_prob.cpu().detach(), max_id.cpu().detach()])
        torch.cuda.empty_cache()

        if i % 50 == 0:
          t2 = time.perf_counter()
          print(f"Finished batch {i + 1} of {num_batches} in {t2 - t1} seconds")

    t_3 = time.perf_counter()
    print(f"Finished entire dataset in {t_3 - t_0} seconds")

    # Returns list of tensors, structure is [[tensor([first batch maximum probabilities]), tensor([corresponding indices/labels])],
    #                                         [tensor([second batch maximum probabilities]), tensor([corresponding indices/labels])],
    #                                         [tensor([third batch maximum probabilities]), tensor([corresponding indices/labels])]]
    return homemade

# %%
# Takes output of homemade_batch as input and returns clean data
def prediction_reformat(subset):
    # Initialize empty list to store new reformatted data
    predicted = []
    count = 0

    # len(subset) = number of batches
    for i in range(len(subset)):
        for k in range(len(subset[0][0])):
            prob = subset[i][0][k].item()
            id = subset[i][1][k].item()

            label = id2label[id]
            predicted.append([count, label, prob, id])

            count += 1

    # Returns nested list with form [[index, "label", probability, id],
    #                                [index, "label", probability, id]]
    return predicted

# %%
# Computes how accurate the model is
def accuracy(result, data_type = "test"):
    correct = 0
    total = 0

    # Create dictionary to count how many of each label occurs in the subset, all labels initialized to 0
    all_labels = {}
    for label in datasets[data_type].features["label"].names:
        all_labels[label] = 0

    # Dictionary to keep track of which classes were incorrectly predicted
    incorrect = {}
    for label in datasets[data_type].features["label"].names:
        incorrect[label] = 0

    # Iterate through the results for each image in the subset
    for i in range(len(result)):
        # Automatically increase count of label in dictionary for appearing
        all_labels[result[i][1]] += 1

        # If the actual id/label aligns with the predicted one, add to correct count
        if datasets[data_type][i]["label"] == result[i][3]:
            correct += 1
            total += 1
            if total % 50 == 0:
              print(f"Model accurately predicted {result[i][1]} with {result[i][2] * 100}% confidence.")
        else:
            # If they do not align, increase count of predicted id/label in incorrect dictionary
            total += 1
            if total % 50 == 0:
              print(f"Model inaccurately predicted {result[i][1]} with {result[i][2] * 100}% confidence.")
            incorrect[result[i][1]] += 1

    print(f"Accuracy: {(correct/total) * 100}%")

    worst_accuracy = []
    # For every label, calculate percentage predicted correctly by subtracting total by incorrect
    for label in all_labels:
        correct =  all_labels[label] - incorrect[label]
        total = all_labels[label]
        print(f"For {label}: Predicted {correct} out of {total} correct. {(correct) / total * 100}% Accuracy")
        worst_accuracy.append([label, correct/total])

    worst_group = min(worst_accuracy, key=lambda x: x[1])
    print(f"The worst performing group is '{worst_group[0]}' with an accuracy of {worst_group[1] * 100}%")

# %%
def data_analysis(predictions, data_type = "test"):
    cleaned = prediction_reformat(predictions)
    final_results = accuracy(cleaned, data_type)

    return final_results

# %%
# Train model on training dataset
def train(num_img, batch_size=10, num_epoch=2):
    # Set up training parameters
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    optimizer = optim.Adam(model.parameters(), lr=1e-5)
    total_loss = 0
    model.to(device)
    model.train()


    for epoch in range(num_epoch):
        t0 = time.perf_counter()
        epoch_loss = 0

        # Separate training data into smaller batches
        for i in range(num_img // batch_size):
            train_set = datasets["train"].select(range(i * batch_size, (i + 1) * batch_size))
            t1 = time.perf_counter()

            # Process the data, feed it into the model
            input = processor(text=labels, images=train_set["img"], return_tensors="pt", padding=False).to(device)
            output = model(**input)

            # Get the logit for the predictions on the image and text
            logits_per_image = output.logits_per_image
            logits_per_text = output.logits_per_text
            # Turn this tensor from batch_size x 1 matrix to 1 x batch_size (doesn't work otherwise)
            logits_per_text = logits_per_text.squeeze()

            # Accesses the ground truth
            targets = torch.tensor(train_set["label"]).to(device)

            # Uses the cross-loss entropy function to calculate the loss of the images and text, utilizes softmax activation
            loss_img = F.cross_entropy(logits_per_image, targets)
            loss_text = F.cross_entropy(logits_per_text, targets)

            # Calculate the total loss
            loss = (loss_img + loss_text) / 2
            t2 = time.perf_counter()
            if i % 50 == 0:
              print(f"Finished batch {i + 1}/{num_img // batch_size} in {t2 - t1} seconds")

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

        t3 = time.perf_counter()
        total_loss += epoch_loss
        avg_loss = epoch_loss / (num_img // batch_size)
        print(f"Epoch {epoch+1}/{num_epoch} completed in {t3 - t1} seconds, Loss: {avg_loss:.4f}")

# %%
pretrained = homemade_batch(5000)
data_analysis(pretrained, data_type = "test")

train(5000, num_epoch=5)

model.eval()

trained = homemade_batch(5000)
data_analysis(trained, data_type = "test")
# Out:
# Finished batch 1 of 500 in 2.433842277999986 seconds
# Finished batch 51 of 500 in 0.646528294999996 seconds
# Finished batch 101 of 500 in 0.6656919849999667 seconds
# Finished batch 151 of 500 in 0.7131715800000507 seconds
# Finished batch 201 of 500 in 0.6775685120000503 seconds
# Finished batch 251 of 500 in 0.6678130189999933 seconds
# Finished batch 301 of 500 in 0.685143223999944 seconds
# Finished batch 351 of 500 in 0.681553603999987 seconds
# Finished batch 401 of 500 in 0.6820611000000554 seconds
# Finished batch 451 of 500 in 0.6742900269999836 seconds
# Finished entire dataset in 340.758512544 seconds
# Model accurately predicted frog with 99.14552569389343% confidence.
# Model accurately predicted horse with 98.48936200141907% confidence.
# Model accurately predicted bird with 98.03536534309387% confidence.
# Model accurately predicted ship with 90.92010259628296% confidence.
# Model accurately predicted bird with 95.06943225860596% confidence.
# Model accurately predicted frog with 99.66448545455933% confidence.
# Model accurately predicted truck with 99.64094758033752% confidence.
# Model accurately predicted cat with 89.27355408668518% confidence.
# Model accurately predicted bird with 97.3240613937378% confidence.
# Model accurately predicted airplane with 58.127784729003906% confidence.
# Model accurately predicted dog with 92.11605787277222% confidence.
# Model accurately predicted cat with 54.88768815994263% confidence.
# Model accurately predicted dog with 95.87952494621277% confidence.
# Model accurately predicted dog with 97.30509519577026% confidence.
# Model accurately predicted dog with 89.12442326545715% confidence.
# Model accurately predicted bird with 75.01824498176575% confidence.
# Model accurately predicted deer with 99.01887774467468% confidence.
# Model accurately predicted dog with 94.13083791732788% confidence.
# Model accurately predicted ship with 63.48728537559509% confidence.
# Model accurately predicted ship with 88.36163878440857% confidence.
# Model accurately predicted deer with 97.96150326728821% confidence.
# Model accurately predicted bird with 94.72103118896484% confidence.
# Model accurately predicted horse with 99.46452379226685% confidence.
# Model accurately predicted truck with 99.00556802749634% confidence.
# Model accurately predicted deer with 74.33201670646667% confidence.
# Model accurately predicted horse with 97.77607917785645% confidence.
# Model accurately predicted ship with 96.90433144569397% confidence.
# Model accurately predicted bird with 92.30720400810242% confidence.
# Model accurately predicted frog with 98.51803779602051% confidence.
# Model accurately predicted ship with 82.46426582336426% confidence.
# Model accurately predicted automobile with 77.3776650428772% confidence.
# Model accurately predicted dog with 94.51401829719543% confidence.
# Model accurately predicted dog with 92.13730692863464% confidence.
# Model accurately predicted horse with 98.43840599060059% confidence.
# Model accurately predicted bird with 85.60045957565308% confidence.
# Model accurately predicted deer with 96.69429063796997% confidence.
# Model accurately predicted horse with 99.51004385948181% confidence.
# Model accurately predicted horse with 99.33578372001648% confidence.
# Model accurately predicted airplane with 79.08878922462463% confidence.
# Model accurately predicted dog with 87.85203695297241% confidence.
# Model accurately predicted cat with 75.28097629547119% confidence.
# Model accurately predicted automobile with 63.720786571502686% confidence.
# Model accurately predicted frog with 99.85496401786804% confidence.
# Model accurately predicted bird with 86.72099113464355% confidence.
# Model accurately predicted airplane with 74.61644411087036% confidence.
# Model inaccurately predicted cat with 87.10859417915344% confidence.
# Model accurately predicted dog with 95.49455046653748% confidence.
# Model accurately predicted ship with 97.68522381782532% confidence.
# Model accurately predicted deer with 79.3901801109314% confidence.
# Model accurately predicted frog with 94.63838338851929% confidence.
# Model inaccurately predicted deer with 64.11846280097961% confidence.
# Model accurately predicted frog with 97.89011478424072% confidence.
# Model accurately predicted frog with 99.58195686340332% confidence.
# Model accurately predicted deer with 99.82073307037354% confidence.
# Model inaccurately predicted automobile with 27.7523010969162% confidence.
# Model accurately predicted ship with 97.63060212135315% confidence.
# Model inaccurately predicted dog with 66.46854877471924% confidence.
# Model accurately predicted truck with 94.80326175689697% confidence.
# Model accurately predicted cat with 65.07583856582642% confidence.
# Model inaccurately predicted horse with 31.38761818408966% confidence.
# Model inaccurately predicted dog with 70.73032259941101% confidence.
# Model accurately predicted truck with 94.08503770828247% confidence.
# Model accurately predicted automobile with 80.50508499145508% confidence.
# Model accurately predicted frog with 99.44084286689758% confidence.
# Model accurately predicted cat with 88.14058899879456% confidence.
# Model accurately predicted airplane with 39.89590108394623% confidence.
# Model accurately predicted frog with 99.69305396080017% confidence.
# Model accurately predicted airplane with 37.341392040252686% confidence.
# Model accurately predicted automobile with 77.25784182548523% confidence.
# Model accurately predicted airplane with 84.89503264427185% confidence.
# Model accurately predicted automobile with 56.912314891815186% confidence.
# Model accurately predicted horse with 99.79137778282166% confidence.
# Model accurately predicted cat with 79.89117503166199% confidence.
# Model accurately predicted truck with 98.1497049331665% confidence.
# Model accurately predicted ship with 74.66724514961243% confidence.
# Model inaccurately predicted dog with 34.01643931865692% confidence.
# Model accurately predicted dog with 98.27028512954712% confidence.
# Model accurately predicted frog with 97.88803458213806% confidence.
# Model accurately predicted dog with 93.09916496276855% confidence.
# Model accurately predicted truck with 96.27776145935059% confidence.
# Model accurately predicted deer with 99.87768530845642% confidence.
# Model accurately predicted deer with 99.75531697273254% confidence.
# Model accurately predicted truck with 97.98232913017273% confidence.
# Model accurately predicted ship with 94.20493841171265% confidence.
# Model accurately predicted deer with 98.55993986129761% confidence.
# Model accurately predicted bird with 67.4106776714325% confidence.
# Model accurately predicted airplane with 88.40098977088928% confidence.
# Model accurately predicted deer with 77.97393798828125% confidence.
# Model accurately predicted truck with 95.29536366462708% confidence.
# Model accurately predicted cat with 87.33792901039124% confidence.
# Model accurately predicted automobile with 83.75197649002075% confidence.
# Model inaccurately predicted automobile with 55.822449922561646% confidence.
# Model accurately predicted ship with 75.8391797542572% confidence.
# Model accurately predicted dog with 84.0942919254303% confidence.
# Model accurately predicted bird with 99.4143545627594% confidence.
# Model accurately predicted automobile with 75.06290674209595% confidence.
# Model accurately predicted dog with 66.71175360679626% confidence.
# Model accurately predicted bird with 99.46377873420715% confidence.
# Model accurately predicted automobile with 90.71027040481567% confidence.
# Model accurately predicted automobile with 87.7968430519104% confidence.
# Accuracy: 91.75999999999999%
# For airplane: Predicted 351 out of 356 correct. 98.59550561797754% Accuracy
# For automobile: Predicted 433 out of 448 correct. 96.65178571428571% Accuracy
# For bird: Predicted 476 out of 590 correct. 80.67796610169492% Accuracy
# For cat: Predicted 443 out of 461 correct. 96.09544468546638% Accuracy
# For deer: Predicted 482 out of 526 correct. 91.63498098859316% Accuracy
# For dog: Predicted 474 out of 540 correct. 87.77777777777777% Accuracy
# For frog: Predicted 445 out of 452 correct. 98.45132743362832% Accuracy
# For horse: Predicted 493 out of 531 correct. 92.8436911487759% Accuracy
# For ship: Predicted 482 out of 497 correct. 96.98189134808854% Accuracy
# For truck: Predicted 509 out of 599 correct. 84.97495826377296% Accuracy
# The worst performing group is 'bird' with an accuracy of 80.67796610169492%
# Finished batch 1/500 in 0.5464726689999679 seconds
# Finished batch 51/500 in 0.5686462319999919 seconds
# Finished batch 101/500 in 0.561135586999967 seconds
# Finished batch 151/500 in 0.5634680099999514 seconds
# Finished batch 201/500 in 0.559932470999911 seconds
# Finished batch 251/500 in 0.5637533859999166 seconds
# Finished batch 301/500 in 0.5676472770001055 seconds
# Finished batch 351/500 in 0.5607178750001367 seconds
# Finished batch 401/500 in 0.559743484000137 seconds
# Finished batch 451/500 in 0.5682559159999983 seconds
# Epoch 1/5 completed in 1.6732182829998692 seconds, Loss: 1.6010
# Finished batch 1/500 in 0.5672593719998531 seconds
# Finished batch 51/500 in 0.567702416999964 seconds
# Finished batch 101/500 in 0.5638031319999754 seconds
# Finished batch 151/500 in 0.5667628499998045 seconds
# Finished batch 201/500 in 0.5685525010001129 seconds
# Finished batch 251/500 in 0.5645397579999099 seconds
# Finished batch 301/500 in 0.5670546159999503 seconds
# Finished batch 351/500 in 0.5637032680001539 seconds
# Finished batch 401/500 in 0.5617299939999612 seconds
# Finished batch 451/500 in 0.569520504999673 seconds
# Epoch 2/5 completed in 1.6695775940002022 seconds, Loss: 1.5078
# Finished batch 1/500 in 0.568169307000062 seconds
# Finished batch 51/500 in 0.5691089229999307 seconds
# Finished batch 101/500 in 0.5647540119998666 seconds
# Finished batch 151/500 in 0.5653878550001536 seconds
# Finished batch 201/500 in 0.5600388110001404 seconds
# Finished batch 251/500 in 0.5769718419996934 seconds
# Finished batch 301/500 in 0.5675554270001157 seconds
# Finished batch 351/500 in 0.5628867250002259 seconds
# Finished batch 401/500 in 0.5693863609999426 seconds
# Finished batch 451/500 in 0.5726803500001552 seconds
# Epoch 3/5 completed in 1.6641335960002834 seconds, Loss: 1.4163
# Finished batch 1/500 in 0.5566535119996843 seconds
# Finished batch 51/500 in 0.5699848089998341 seconds
# Finished batch 101/500 in 0.5634912820000864 seconds
# Finished batch 151/500 in 0.5763261110000713 seconds
# Finished batch 201/500 in 0.5630748170001425 seconds
# Finished batch 251/500 in 0.5606745740001315 seconds
# Finished batch 301/500 in 0.5761931899996853 seconds
# Finished batch 351/500 in 0.5612952970000151 seconds
# Finished batch 401/500 in 0.5680796579999878 seconds
# Finished batch 451/500 in 0.5694653360001212 seconds
# Epoch 4/5 completed in 1.670011808000254 seconds, Loss: 1.1793
# Finished batch 1/500 in 0.5665138520002984 seconds
# Finished batch 51/500 in 0.5601348929999403 seconds
# Finished batch 101/500 in 0.5726774410004509 seconds
# Finished batch 151/500 in 0.566065123000044 seconds
# Finished batch 201/500 in 0.5694538830002784 seconds
# Finished batch 251/500 in 0.5658461399998487 seconds
# Finished batch 301/500 in 0.5619644700000208 seconds
# Finished batch 351/500 in 0.5686772140006724 seconds
# Finished batch 401/500 in 0.5755494639997778 seconds
# Finished batch 451/500 in 0.5691291639996052 seconds
# Epoch 5/5 completed in 1.6772160669997902 seconds, Loss: 0.9184
# Finished batch 1 of 500 in 0.654588696999781 seconds
# Finished batch 51 of 500 in 0.6875472490000902 seconds
# Finished batch 101 of 500 in 0.7169576229998711 seconds
# Finished batch 151 of 500 in 0.6908028009993359 seconds
# Finished batch 201 of 500 in 0.6874323179999919 seconds
# Finished batch 251 of 500 in 0.6893955290006488 seconds
# Finished batch 301 of 500 in 0.7115746139998009 seconds
# Finished batch 351 of 500 in 0.6889962200002628 seconds
# Finished batch 401 of 500 in 0.6907682110004316 seconds
# Finished batch 451 of 500 in 0.6927697400005854 seconds
# Finished entire dataset in 350.66077466000024 seconds
# Model accurately predicted frog with 91.15597605705261% confidence.
# Model accurately predicted horse with 83.58215689659119% confidence.
# Model accurately predicted bird with 56.35940432548523% confidence.
# Model accurately predicted ship with 89.98823761940002% confidence.
# Model accurately predicted bird with 84.75443720817566% confidence.
# Model accurately predicted frog with 90.37057757377625% confidence.
# Model accurately predicted truck with 53.82181406021118% confidence.
# Model accurately predicted cat with 90.36568999290466% confidence.
# Model accurately predicted bird with 69.26316022872925% confidence.
# Model accurately predicted airplane with 55.57538866996765% confidence.
# Model accurately predicted dog with 95.19410133361816% confidence.
# Model accurately predicted cat with 65.74741005897522% confidence.
# Model accurately predicted dog with 82.9269528388977% confidence.
# Model accurately predicted dog with 78.31761837005615% confidence.
# Model accurately predicted dog with 98.38799834251404% confidence.
# Model accurately predicted bird with 32.79241621494293% confidence.
# Model accurately predicted deer with 72.49991297721863% confidence.
# Model accurately predicted dog with 96.9148576259613% confidence.
# Model accurately predicted ship with 68.91334056854248% confidence.
# Model accurately predicted ship with 86.95268630981445% confidence.
# Model accurately predicted deer with 62.19462752342224% confidence.
# Model accurately predicted bird with 46.48664593696594% confidence.
# Model accurately predicted horse with 91.99405908584595% confidence.
# Model accurately predicted truck with 82.62478113174438% confidence.
# Model accurately predicted deer with 61.51670217514038% confidence.
# Model accurately predicted horse with 89.94833827018738% confidence.
# Model accurately predicted ship with 88.92487287521362% confidence.
# Model accurately predicted bird with 61.90308332443237% confidence.
# Model accurately predicted frog with 84.0657889842987% confidence.
# Model accurately predicted ship with 80.2302360534668% confidence.
# Model accurately predicted automobile with 99.44249391555786% confidence.
# Model accurately predicted dog with 84.03934240341187% confidence.
# Model accurately predicted dog with 86.19946837425232% confidence.
# Model accurately predicted horse with 60.17305850982666% confidence.
# Model accurately predicted bird with 77.15237736701965% confidence.
# Model accurately predicted deer with 92.07491874694824% confidence.
# Model accurately predicted horse with 74.66009855270386% confidence.
# Model accurately predicted horse with 53.569966554641724% confidence.
# Model accurately predicted airplane with 55.64107298851013% confidence.
# Model accurately predicted dog with 80.86729049682617% confidence.
# Model accurately predicted cat with 41.98733568191528% confidence.
# Model accurately predicted automobile with 96.42910361289978% confidence.
# Model accurately predicted frog with 88.65488171577454% confidence.
# Model accurately predicted bird with 86.43003702163696% confidence.
# Model accurately predicted airplane with 82.44699239730835% confidence.
# Model accurately predicted frog with 34.150707721710205% confidence.
# Model accurately predicted dog with 91.35045409202576% confidence.
# Model accurately predicted ship with 83.95329117774963% confidence.
# Model accurately predicted deer with 67.95405745506287% confidence.
# Model accurately predicted frog with 82.90017247200012% confidence.
# Model accurately predicted frog with 90.16034603118896% confidence.
# Model accurately predicted frog with 93.28334927558899% confidence.
# Model accurately predicted frog with 75.51727890968323% confidence.
# Model accurately predicted deer with 64.80241417884827% confidence.
# Model accurately predicted airplane with 52.33445763587952% confidence.
# Model accurately predicted ship with 98.13738465309143% confidence.
# Model accurately predicted frog with 36.712414026260376% confidence.
# Model inaccurately predicted frog with 31.235653162002563% confidence.
# Model accurately predicted cat with 80.37038445472717% confidence.
# Model accurately predicted frog with 86.69590353965759% confidence.
# Model inaccurately predicted dog with 87.63175010681152% confidence.
# Model accurately predicted truck with 87.17029094696045% confidence.
# Model accurately predicted automobile with 54.56000566482544% confidence.
# Model accurately predicted frog with 77.16581225395203% confidence.
# Model accurately predicted cat with 86.61927580833435% confidence.
# Model inaccurately predicted frog with 29.693710803985596% confidence.
# Model accurately predicted frog with 92.98789501190186% confidence.
# Model accurately predicted airplane with 83.79181623458862% confidence.
# Model accurately predicted automobile with 98.16694855690002% confidence.
# Model accurately predicted airplane with 65.61670303344727% confidence.
# Model accurately predicted automobile with 80.00122308731079% confidence.
# Model accurately predicted horse with 77.60155200958252% confidence.
# Model accurately predicted cat with 89.7896409034729% confidence.
# Model inaccurately predicted automobile with 54.106128215789795% confidence.
# Model accurately predicted ship with 95.79703211784363% confidence.
# Model inaccurately predicted bird with 35.96644401550293% confidence.
# Model accurately predicted dog with 88.80165815353394% confidence.
# Model accurately predicted frog with 77.63014435768127% confidence.
# Model accurately predicted dog with 74.4834303855896% confidence.
# Model accurately predicted truck with 83.43815803527832% confidence.
# Model accurately predicted deer with 73.89246225357056% confidence.
# Model accurately predicted deer with 78.59500050544739% confidence.
# Model accurately predicted truck with 49.48936700820923% confidence.
# Model accurately predicted ship with 77.06284523010254% confidence.
# Model accurately predicted deer with 51.42820477485657% confidence.
# Model inaccurately predicted deer with 33.81091356277466% confidence.
# Model accurately predicted airplane with 51.46171450614929% confidence.
# Model accurately predicted deer with 82.30798840522766% confidence.
# Model inaccurately predicted automobile with 32.930153608322144% confidence.
# Model inaccurately predicted dog with 65.06883502006531% confidence.
# Model accurately predicted automobile with 84.47422981262207% confidence.
# Model accurately predicted ship with 65.28120040893555% confidence.
# Model accurately predicted ship with 68.48254203796387% confidence.
# Model accurately predicted dog with 63.18131685256958% confidence.
# Model accurately predicted bird with 83.97661447525024% confidence.
# Model accurately predicted automobile with 90.25578498840332% confidence.
# Model inaccurately predicted frog with 49.30935502052307% confidence.
# Model accurately predicted bird with 58.80458354949951% confidence.
# Model accurately predicted automobile with 64.77594375610352% confidence.
# Model accurately predicted automobile with 79.17501330375671% confidence.
# Accuracy: 86.0%
# For airplane: Predicted 424 out of 439 correct. 96.58314350797266% Accuracy
# For automobile: Predicted 501 out of 674 correct. 74.33234421364985% Accuracy
# For bird: Predicted 418 out of 434 correct. 96.31336405529954% Accuracy
# For cat: Predicted 268 out of 283 correct. 94.69964664310953% Accuracy
# For deer: Predicted 472 out of 516 correct. 91.47286821705426% Accuracy
# For dog: Predicted 432 out of 629 correct. 68.68044515103338% Accuracy
# For frog: Predicted 479 out of 646 correct. 74.14860681114551% Accuracy
# For horse: Predicted 454 out of 480 correct. 94.58333333333333% Accuracy
# For ship: Predicted 490 out of 526 correct. 93.15589353612167% Accuracy
# For truck: Predicted 362 out of 373 correct. 97.05093833780161% Accuracy
# The worst performing group is 'dog' with an accuracy of 68.68044515103338%
